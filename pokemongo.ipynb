# %% [markdown]
# # Example: arranging your Pokémon by attack power

# %%
import pokemongo as pg

my_pokemon = pg.read_csv("""
Pokemon      CP  Move1        Move2
Arcanine   1522  FireFang     Bulldoze
Arcanine   1356  FireFang     Flamethrower
Rhydon     1192  MudSlap      Earthquake
Pinsir     1118  FuryCutter   Submission
Pidgeot    1094  WingAttack   Hurricane
Rhydon     1057  MudSlap      Megahorn
Sandslash  1031  MudShot      Earthquake
Magmar     1026  Ember        Flamethrower
Arbok       981  Acid         SludgeWave
Weepinbell  950  Acid         PowerWhip
Golbat      943  Bite         OminousWind
Flareon     927  Ember        HeatWave
Tauros      919  ZenHeadbutt  Earthquake
Ivysaur     873  VineWhip     SludgeBomb
Fearow      869  Peck         DrillRun
Lickitung   854  Lick         Stomp
Venomoth    840  Confusion    PoisonFang
Graveler    804  MudShot      RockSlide
Marowak     779  MudSlap      Dig
Raticate    768  QuickAttack  HyperFang
Jolteon     766  ThunderShock Thunder
Primeape    751  KarateChop   LowSweep
Aerodactyl  677  Bite         IronHead
Growlithe   592  Ember        BodySlam
Machoke     584  LowKick      BrickBreak
Dodrio      562  FeintAttack  AerialAce
Squirtle    561  Bubble       AquaTail
""")

# Compute Damage Per Second of the first move.
my_pokemon['DPS1'] = my_pokemon.apply(
    lambda p: round(pg.get_dps(p, p.Move1) * pg.types.loc[p.Pokemon].Attack / 250, 1), axis=1)

# Compute Damage Per Second of the second move.
my_pokemon['DPS2'] = my_pokemon.apply(
    lambda p: round(pg.get_dps(p, p.Move2) * pg.types.loc[p.Pokemon].Attack / 250, 1), axis=1)

# Compute attack power.
my_pokemon['Avg DPS'] = my_pokemon.apply(
    lambda p: (p.DPS1 + p.DPS2) / 2, axis=1)
my_pokemon.sort_values('Avg DPS', ascending=False)
# Out:
#        Pokemon    CP         Move1         Move2  DPS1  DPS2  Avg DPS
# 11     Flareon   927         Ember      HeatWave  11.3  25.0    18.15
# 1     Arcanine  1356      FireFang  Flamethrower  13.7  21.8    17.75
# 9   Weepinbell   950          Acid     PowerWhip   9.0  23.8    16.40
# 4      Pidgeot  1094    WingAttack     Hurricane  10.2  21.3    15.75
# 7       Magmar  1026         Ember  Flamethrower  10.2  20.3    15.25
# 20     Jolteon   766  ThunderShock       Thunder   8.0  22.3    15.15
# 2       Rhydon  1192       MudSlap    Earthquake   9.2  19.8    14.50
# 6    Sandslash  1031       MudShot    Earthquake   8.2  17.9    13.05
# 5       Rhydon  1057       MudSlap      Megahorn   9.2  16.6    12.90
# 8        Arbok   981          Acid    SludgeWave   7.9  17.1    12.50
# 13     Ivysaur   873      VineWhip    SludgeBomb   8.4  16.5    12.45
# 23   Growlithe   592         Ember      BodySlam   7.4  16.0    11.70
# 0     Arcanine  1522      FireFang      Bulldoze  13.7   9.5    11.60
# 12      Tauros   919   ZenHeadbutt    Earthquake   6.7  14.1    10.40
# 24     Machoke   584       LowKick    BrickBreak   6.4  14.4    10.40
# 22  Aerodactyl   677          Bite      IronHead   8.7  10.9     9.80
# 17    Graveler   804       MudShot     RockSlide   7.7  11.1     9.40
# 21    Primeape   751    KarateChop      LowSweep   6.7  11.9     9.30
# 25      Dodrio   562   FeintAttack     AerialAce   8.4   9.4     8.90
# 19    Raticate   768   QuickAttack     HyperFang   5.5  12.1     8.80
# 3       Pinsir  1118    FuryCutter    Submission   6.9  10.5     8.70
# 14      Fearow   869          Peck      DrillRun   7.3   9.9     8.60
# 26    Squirtle   561        Bubble      AquaTail   6.1  10.7     8.40
# 18     Marowak   779       MudSlap           Dig   7.8   8.5     8.15
# 16    Venomoth   840     Confusion    PoisonFang   6.8   8.9     7.85
# 10      Golbat   943          Bite   OminousWind   7.9   6.4     7.15
# 15   Lickitung   854          Lick         Stomp   5.0   9.0     7.00
